# %%
# Import the modules

import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.preprocessing import StandardScaler
import hvplot.pandas

# %%
# Read CSV File (AllOthers.csv)

csvpath = Path("Projects/03-Project3/AllOthers.csv")

# %%
# Create All Others DataFrame

all_others_df = pd.read_csv(Path("AllOthers.csv"), parse_dates=True, index_col="Quarter", infer_datetime_format=True)

# %%
# Review the DataFrame 

all_others_df
# Out:
#                                                  All other  \
# Quarter
# NaN                  Total Store and\r\nNon-store\r\nSales
# 2nd quarter 2023(p)                                618,920
# 1st quarter 2023(r)                                577,979
# 4th quarter 2022                                   636,216
# 3rd quarter 2022                                   639,441
# 2nd quarter 2022                                   643,628
# 1st quarter 2022                                   561,649
# 4th quarter 2021                                   591,433
# 3rd quarter 2021                                   564,627
# 2nd quarter 2021                                   545,229
# 1st quarter 2021                                   490,580
# 4th quarter 2020                                   504,916
# 3rd quarter 2020                                   495,099
# 2nd quarter 2020                                   458,574
# 1st quarter 2020                                   469,246
# ...

# %%
# Create an hvplot

all_others_df.hvplot(
    title="All Others - Food & Beverage, Health & Personal Care, Sporting Goods, Musical Instruments, Gas Stations, etc.",
    xlabel="period",
    ylabel="percentage_%",
    rot=90,
    width=2000,
    height=500
)

# looking to create a side-by-side bar or line chart which shows the progression of sales in e-commerce from 2018 onwards 
# Have separte graphs for: 1) Total Commerce, 2) Total e-commerce, and then 3) combine the graphs into one
# Out:
# :NdOverlay   [Variable]
#    :Curve   [Quarter]   (value)
